# %%
import pandas as pd
import config as cfg
from utils import open_gz_by_district
import tarfile

# %%
file = tarfile.open(cfg.VIAJES_DATA / '202104_maestra1_mitma_distrito.tar') # open file, a zipped folder containing all data monthly (typically in .tar format)
file.extractall(cfg.VIAJES_DATA / 'test') # extracting file, unzipped folder containing several files
file.close()

# %%
df = pd.read_csv('/Users/caro/Desktop/thesis_project/mobility_data/VIAJES/test/20210401_maestra_1_mitma_distrito.txt.gz', compression='gzip', sep='|', decimal='.')
# Out:
# /var/folders/5y/mx06x73d0yb7mfb57y7lb2nh0000gn/T/ipykernel_26336/1512575668.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/caro/Desktop/thesis_project/mobility_data/VIAJES/test/20210401_maestra_1_mitma_distrito.txt.gz', compression='gzip', sep='|', decimal='.')

# %%
df.head(20)
# Out:
#        fecha    origen   destino actividad_origen actividad_destino  \
# 0   20210401  01001_AM  01001_AM             casa             otros
# 1   20210401  01001_AM  01001_AM             casa             otros
# 2   20210401  01001_AM  01001_AM             casa             otros
# 3   20210401  01001_AM  01001_AM             casa             otros
# 4   20210401  01001_AM  01001_AM             casa             otros
# 5   20210401  01001_AM  01001_AM             casa             otros
# 6   20210401  01001_AM  01001_AM             casa             otros
# 7   20210401  01001_AM  01001_AM             casa             otros
# 8   20210401  01001_AM  01001_AM             casa             otros
# 9   20210401  01001_AM  01001_AM             casa             otros
# 10  20210401  01001_AM  01001_AM             casa             otros
# 11  20210401  01001_AM  01001_AM             casa             otros
# 12  20210401  01001_AM  01001_AM             casa             otros
# ...

# %%
all_viajes = pd.read_csv(cfg.VIAJES_DATA / 'all_viajes_month_0322.csv')
df = all_viajes.loc[(all_viajes['actividad_origen'] == 'casa')]
test = pd.read_csv(cfg.VIAJES_DATA / 'TEST_viajes_week_0322.csv')

# %%
test.viajes.describe()
# Out:
# count    1.361784e+06
# mean     1.294552e+01
# std      3.200773e+01
# min      1.000000e+00
# 25%      3.230000e+00
# 50%      5.556000e+00
# 75%      1.087500e+01
# max      1.252723e+03
# Name: viajes, dtype: float64

# %%
test.viajes.describe()
# Out:
# count    1.361784e+06
# mean     1.294552e+01
# std      3.200773e+01
# min      1.000000e+00
# 25%      3.230000e+00
# 50%      5.556000e+00
# 75%      1.087500e+01
# max      1.252723e+03
# Name: viajes, dtype: float64

# %%
type(test.viajes[0])
# Out:
# numpy.float64

# %%
all_viajes.viajes.describe()
# Out:
# count    1.990096e+07
# mean     1.256181e+01
# std      2.997316e+01
# min      1.000000e+00
# 25%      3.319000e+00
# 50%      5.478000e+00
# 75%      1.078300e+01
# max      1.254067e+03
# Name: viajes, dtype: float64

# %%
all_viajes
# Out:
#              fecha  periodo   origen  destino distancia actividad_origen  \
# 0         20220301        0  2807901  2807901     0.5-2             casa
# 1         20220301        0  2807901  2807901     0.5-2             casa
# 2         20220301        0  2807901  2807901     0.5-2             casa
# 3         20220301        0  2807901  2807901     0.5-2             casa
# 4         20220301        0  2807901  2807901     0.5-2             casa
# ...            ...      ...      ...      ...       ...              ...
# 19900950  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900951  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900952  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900953  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900954  20220331       23  2807921  2807921      2-10  trabajo_estudio
#
#          actividad_destino estudio_origen_posible estudio_destino_posible  \
# ...

# %%
all_viajes.shape
# Out:
# (19900955, 15)

# %%
df.shape
# Out:
# (4839108, 15)

# %%
import pandas as pd
# all_viajes = pd.read_csv('/Users/caro/Desktop/thesis_project/mobility_data/VIAJES/all_viajes_month_0322.csv') # all trips

df['viajes'] = df['viajes'] * 1000
df['viajes_km'] = df['viajes_km'] * 1000
# Out:
# /var/folders/5y/mx06x73d0yb7mfb57y7lb2nh0000gn/T/ipykernel_15403/2576502206.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['viajes'] = df['viajes'] * 1000
# /var/folders/5y/mx06x73d0yb7mfb57y7lb2nh0000gn/T/ipykernel_15403/2576502206.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['viajes_km'] = df['viajes_km'] * 1000

# %%
all_viajes
# Out:
#              fecha  periodo   origen  destino distancia actividad_origen  \
# 0         20220301        0  2807901  2807901     0.5-2             casa
# 1         20220301        0  2807901  2807901     0.5-2             casa
# 2         20220301        0  2807901  2807901     0.5-2             casa
# 3         20220301        0  2807901  2807901     0.5-2             casa
# 4         20220301        0  2807901  2807901     0.5-2             casa
# ...            ...      ...      ...      ...       ...              ...
# 19900950  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900951  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900952  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900953  20220331       23  2807921  2807921      2-10  trabajo_estudio
# 19900954  20220331       23  2807921  2807921      2-10  trabajo_estudio
#
#          actividad_destino estudio_origen_posible estudio_destino_posible  \
# ...

# %%
all_viajes['viajes'] = all_viajes['viajes'].apply(lambda x: float(str(x).replace('.', '').replace(',', '.')))
all_viajes['viajes_km'] = all_viajes['viajes_km'].apply(lambda x: float(str(x).replace('.', '').replace(',', '.')))

# %%
all_viajes.viajes.describe()
# Out:
# count    1.990096e+07
# mean     9.016490e+08
# std      2.116836e+10
# min      1.000000e+01
# 25%      2.855000e+03
# 50%      4.473000e+03
# 75%      9.617000e+03
# max      9.997415e+11
# Name: viajes, dtype: float64
