# %%
import pandas as pd

# %%
# SOURCE: https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=71359583a773a510VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default


all_sheets = pd.ExcelFile('panel_indicadores_distritos_barrios_2023.xlsx').sheet_names

# Skip the first two sheets
sheets_to_load = all_sheets[2:]

# Load all the remaining sheets into a dictionary of DataFrames
data_frames = pd.read_excel('panel_indicadores_distritos_barrios_2023.xlsx', sheet_name=sheets_to_load)

# If you want to work with a specific sheet
specific_sheet_df = data_frames['CENTRO']

# %%
specific_sheet_df
# Out:
#      Unnamed: 0       1. CENTRO. INFORMACIÓN DE DISTRITO Y BARRIOS Unnamed: 2  \
# 0           NaN                                                        CIUDAD
# 1           NaN  1.1 CARACTERÍSTICAS GENERALES DEL DISTRITO-BARRIO        NaN
# 2           NaN                                  Superficie (Ha.)    60445.52
# 3           NaN                               Densidad (hab./Ha.)   55.255228
# 4           NaN                     1.2. LA POBLACIÓN DEL DISTRITO        NaN
# ..          ...                                                ...        ...
# 378         NaN                            PARTICIPACIÓN CIUDADANA     924.01
# 379         NaN                                 SALUBRIDAD PÚBLICA     311.01
# 380         NaN                SERVICIOS COMPLEMENTARIOS EDUCACIÓN     326.01
# 381         NaN             SERVICIOS SOCIALES Y EMERGENCIA SOCIAL     231.06
# 382         NaN                                        SECCIÓN 201        NaN
#
# ...
